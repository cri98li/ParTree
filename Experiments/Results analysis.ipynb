# %%
import os
from glob import glob
import psutil
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# %%
[y for x in os.walk("final_joined_result/") for y in glob(os.path.join(x[0], '*.csv'))]
# Out:
# ['final_joined_result\\2d-20c-no0_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-20c-no0_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-20c-no0_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-3c-no123_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-3c-no123_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-3c-no123_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-4c-no9_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-4c-no9_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-4c-no9_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-4c_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-4c_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-4c_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-d31_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-d31_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-d31_y.zip PrincipalParTree.csv',
#  'final_joined_result\\aggregation_y.zip PrincipalParTree.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip CenterParTree2.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip PrincipalParTree.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip CenterParTree2.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip PrincipalParTree.csv',
#  'final_joined_result\\cure-t2-4k_y.zip CenterParTree2.csv',
#  'final_joined_result\\cure-t2-4k_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\cure-t2-4k_y.zip PrincipalParTree.csv',
#  'final_joined_result\\german_credit_y.zip CenterParTree2.csv',
#  'final_joined_result\\german_credit_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\german_credit_y.zip PrincipalParTree.csv',
#  'final_joined_result\\home.zip CenterParTree2.csv',
#  'final_joined_result\\home.zip ImpurityParTree2.csv',
#  'final_joined_result\\home.zip PrincipalParTree.csv',
#  'final_joined_result\\ionosphere_y.zip PrincipalParTree.csv',
#  'final_joined_result\\iris_y.zip PrincipalParTree.csv',
#  'final_joined_result\\longsquare_y.zip CenterParTree2.csv',
#  'final_joined_result\\longsquare_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\longsquare_y.zip PrincipalParTree.csv',
#  'final_joined_result\\s-set1_y.zip CenterParTree2.csv',
#  'final_joined_result\\s-set1_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\s-set1_y.zip PrincipalParTree.csv',
#  'final_joined_result\\s-set2_y.zip CenterParTree2.csv',
#  'final_joined_result\\s-set2_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\s-set2_y.zip PrincipalParTree.csv',
#  'final_joined_result\\tetra_y.zip CenterParTree2.csv',
#  'final_joined_result\\tetra_y.zip PrincipalParTree.csv',
#  'final_joined_result\\titanic_y.zip CenterParTree2.csv',
#  'final_joined_result\\titanic_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\titanic_y.zip PrincipalParTree.csv',
#  'final_joined_result\\triangle1_y.zip CenterParTree2.csv',
#  'final_joined_result\\triangle1_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\triangle1_y.zip PrincipalParTree.csv',
#  'final_joined_result\\triangle2_y.zip CenterParTree2.csv',
#  'final_joined_result\\triangle2_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\triangle2_y.zip PrincipalParTree.csv',
#  'final_joined_result\\vehicle_y.zip PrincipalParTree.csv',
#  'final_joined_result\\wdbc_y.zip CenterParTree2.csv',
#  'final_joined_result\\wdbc_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\wdbc_y.zip PrincipalParTree.csv',
#  'final_joined_result\\wine.zip CenterParTree2.csv',
#  'final_joined_result\\wine.zip ImpurityParTree2.csv',
#  'final_joined_result\\wine.zip PrincipalParTree.csv',
#  'final_joined_result\\zelnik5_y.zip PrincipalParTree.csv',
#  'final_joined_result\\zelnik6_y.zip CenterParTree2.csv',
#  'final_joined_result\\zelnik6_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\zelnik6_y.zip PrincipalParTree.csv']

# %%
df_Center = pd.read_csv("final_joined_result/2d-3c-no123_y.zip CenterParTree2.csv")
df_Impurity = pd.read_csv("final_joined_result/2d-3c-no123_y.zip ImpurityParTree2.csv")
df_Principal = pd.read_csv("final_joined_result/2d-3c-no123_y.zip PrincipalParTree.csv")

# %%
df_Center.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                 3                30                 50
# 1         10                 3                30                 50
# 2         10                 3                30                 50
# 3         10                 3                30                 50
# 4         10                 3                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state metric_con  \
# 0          1000.0               100.0      0.0            42        cos
# 1          1000.0               100.0      0.1            42        cos
# 2          1000.0               100.0      0.2            42        cos
# 3          1000.0                20.0      0.0            42        cos
# 4          1000.0                20.0      0.1            42        cos
#
#   metric_cat  ...  adj_rand  mut_info_score  adj_mutual_info_score  \
# 0    jaccard  ...    0.0000          0.0000                 0.0000
# 1    jaccard  ...    0.0009          0.0028                 0.0002
# 2    jaccard  ...    0.0009          0.0028                 0.0002
# 3    jaccard  ...    0.0000          0.0000                 0.0000
# 4    jaccard  ...    0.0009          0.0028                 0.0002
#
#    norm_mutual_info_score  homog_score  complete_score  v_msr_score  \
# 0                  0.0000       0.0000          1.0000       0.0000
# 1                  0.0057       0.0029          0.1319       0.0057
# 2                  0.0057       0.0029          0.1319       0.0057
# 3                  0.0000       0.0000          1.0000       0.0000
# 4                  0.0057       0.0029          0.1319       0.0057
#
#    fwlks_mallows_score             alg            dataset
# 0               0.6451  CenterParTree2  2d-3c-no123_y.zip
# 1               0.6437  CenterParTree2  2d-3c-no123_y.zip
# 2               0.6437  CenterParTree2  2d-3c-no123_y.zip
# 3               0.6451  CenterParTree2  2d-3c-no123_y.zip
# 4               0.6437  CenterParTree2  2d-3c-no123_y.zip
#
# [5 rows x 25 columns]

# %%
df_Impurity.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                 3                30                 50
# 1         10                 3                30                 50
# 2         10                 3                30                 50
# 3         10                 3                30                 50
# 4         10                 3                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state criteria_clf  \
# 0          1000.0               100.0      0.0            42      entropy
# 1          1000.0               100.0      0.0            42      entropy
# 2          1000.0               100.0      0.0            42         gini
# 3          1000.0               100.0      0.0            42         gini
# 4          1000.0               100.0      0.0            42           me
#
#   criteria_reg  ...  adj_rand  mut_info_score  adj_mutual_info_score  \
# 0         mape  ...    0.4865          0.5716                 0.5737
# 1           r2  ...    0.0000          0.0000                 0.0000
# 2         mape  ...    0.4865          0.5716                 0.5737
# 3           r2  ...    0.0000          0.0000                 0.0000
# 4         mape  ...    0.4865          0.5716                 0.5737
#
#    norm_mutual_info_score  homog_score  complete_score  v_msr_score  \
# 0                  0.5749       0.5982          0.5534       0.5749
# 1                  0.0000       0.0000          1.0000       0.0000
# 2                  0.5749       0.5982          0.5534       0.5749
# 3                  0.0000       0.0000          1.0000       0.0000
# 4                  0.5749       0.5982          0.5534       0.5749
#
#    fwlks_mallows_score               alg            dataset
# 0               0.6897  ImpurityParTree2  2d-3c-no123_y.zip
# 1               0.6451  ImpurityParTree2  2d-3c-no123_y.zip
# 2               0.6897  ImpurityParTree2  2d-3c-no123_y.zip
# 3               0.6451  ImpurityParTree2  2d-3c-no123_y.zip
# 4               0.6897  ImpurityParTree2  2d-3c-no123_y.zip
#
# [5 rows x 25 columns]

# %%
df_Principal.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                 3                30                 50
# 1         10                 3                30                 50
# 2         10                 3                30                 50
# 3         10                 3                30                 50
# 4         10                 3                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state  n_components  \
# 0          1000.0                 100      0.0            42             1
# 1          1000.0                 100      0.0            42             1
# 2          1000.0                 100      0.0            42             1
# 3          1000.0                 100      0.0            42             1
# 4          1000.0                 100      0.0            42             2
#
#    oblique_splits  ...  adj_rand  mut_info_score  adj_mutual_info_score  \
# 0           False  ...    0.8569          0.7781                 0.8248
# 1           False  ...    0.8569          0.7781                 0.8248
# 2           False  ...    0.8569          0.7781                 0.8248
# 3           False  ...    0.8569          0.7781                 0.8248
# 4           False  ...    0.8569          0.7781                 0.8248
#
#    norm_mutual_info_score  homog_score  complete_score  v_msr_score  \
# 0                  0.8253       0.8144          0.8365       0.8253
# 1                  0.8253       0.8144          0.8365       0.8253
# 2                  0.8253       0.8144          0.8365       0.8253
# 3                  0.8253       0.8144          0.8365       0.8253
# 4                  0.8253       0.8144          0.8365       0.8253
#
#    fwlks_mallows_score               alg            dataset
# 0               0.9179  PrincipalParTree  2d-3c-no123_y.zip
# 1               0.9179  PrincipalParTree  2d-3c-no123_y.zip
# 2               0.9179  PrincipalParTree  2d-3c-no123_y.zip
# 3               0.9179  PrincipalParTree  2d-3c-no123_y.zip
# 4               0.9179  PrincipalParTree  2d-3c-no123_y.zip
#
# [5 rows x 26 columns]

# %%
df_concat = pd.concat([df_Center, df_Principal, df_Impurity])
df_concat.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                 3                30                 50
# 1         10                 3                30                 50
# 2         10                 3                30                 50
# 3         10                 3                30                 50
# 4         10                 3                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state metric_con  \
# 0          1000.0               100.0      0.0            42        cos
# 1          1000.0               100.0      0.1            42        cos
# 2          1000.0               100.0      0.2            42        cos
# 3          1000.0                20.0      0.0            42        cos
# 4          1000.0                20.0      0.1            42        cos
#
#   metric_cat  ...  complete_score  v_msr_score  fwlks_mallows_score  \
# 0    jaccard  ...          1.0000       0.0000               0.6451
# 1    jaccard  ...          0.1319       0.0057               0.6437
# 2    jaccard  ...          0.1319       0.0057               0.6437
# 3    jaccard  ...          1.0000       0.0000               0.6451
# 4    jaccard  ...          0.1319       0.0057               0.6437
#
#               alg            dataset  n_components  oblique_splits  \
# 0  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 1  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 2  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 3  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 4  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
#
#    max_oblique_features  criteria_clf  criteria_reg
# 0                   NaN           NaN           NaN
# 1                   NaN           NaN           NaN
# 2                   NaN           NaN           NaN
# 3                   NaN           NaN           NaN
# 4                   NaN           NaN           NaN
#
# [5 rows x 30 columns]

# %%
df_concat.groupby(by=["alg"])["silhouette"].max()
# Out:
# alg
# CenterParTree2      0.2779
# ImpurityParTree2    0.4084
# PrincipalParTree    0.4848
# Name: silhouette, dtype: float64

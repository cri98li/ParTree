# %%
import os
from glob import glob
import psutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# %%
risultati = [y for x in os.walk("final_joined_result/") for y in glob(os.path.join(x[0], '*.csv'))]
risultati
# Out:
# ['final_joined_result\\2d-20c-no0_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-20c-no0_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-20c-no0_y.zip kmodes.csv',
#  'final_joined_result\\2d-20c-no0_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-20c-no0_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\2d-20c-no0_y.zip pyc_xmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\2d-20c-no0_y.zip skl_birch.csv',
#  'final_joined_result\\2d-20c-no0_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\2d-20c-no0_y.zip skl_OPTICS.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-20_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-20_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\2d-20c-no0_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-3c-no123_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-3c-no123_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-3c-no123_y.zip kmodes.csv',
#  'final_joined_result\\2d-3c-no123_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-3c-no123_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\2d-3c-no123_y.zip pyc_xmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\2d-3c-no123_y.zip skl_birch.csv',
#  'final_joined_result\\2d-3c-no123_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\2d-3c-no123_y.zip skl_OPTICS.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-3_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-3_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\2d-3c-no123_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c-no9_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-4c-no9_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-4c-no9_y.zip kmodes.csv',
#  'final_joined_result\\2d-4c-no9_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-4c-no9_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\2d-4c-no9_y.zip pyc_xmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\2d-4c-no9_y.zip skl_birch.csv',
#  'final_joined_result\\2d-4c-no9_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\2d-4c-no9_y.zip skl_OPTICS.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c-no9_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-4c_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-4c_y.zip kmodes.csv',
#  'final_joined_result\\2d-4c_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-4c_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\2d-4c_y.zip pyc_xmeans.csv',
#  'final_joined_result\\2d-4c_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\2d-4c_y.zip skl_birch.csv',
#  'final_joined_result\\2d-4c_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\2d-4c_y.zip skl_OPTICS.csv',
#  'final_joined_result\\2d-4c_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-4c_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\2d-4c_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-d31_y.zip CenterParTree2.csv',
#  'final_joined_result\\2d-d31_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\2d-d31_y.zip kmodes.csv',
#  'final_joined_result\\2d-d31_y.zip PrincipalParTree.csv',
#  'final_joined_result\\2d-d31_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\2d-d31_y.zip pyc_xmeans.csv',
#  'final_joined_result\\2d-d31_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\2d-d31_y.zip skl_birch.csv',
#  'final_joined_result\\2d-d31_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\2d-d31_y.zip skl_OPTICS.csv',
#  'final_joined_result\\2d-d31_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-d31_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-d31_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-d31_y.zip-31_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-31_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-d31_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\2d-d31_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\2d-d31_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\aggregation_y.zip CenterParTree2.csv',
#  'final_joined_result\\aggregation_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\aggregation_y.zip kmodes.csv',
#  'final_joined_result\\aggregation_y.zip PrincipalParTree.csv',
#  'final_joined_result\\aggregation_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\aggregation_y.zip pyc_xmeans.csv',
#  'final_joined_result\\aggregation_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\aggregation_y.zip skl_birch.csv',
#  'final_joined_result\\aggregation_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\aggregation_y.zip skl_OPTICS.csv',
#  'final_joined_result\\aggregation_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\aggregation_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\aggregation_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\aggregation_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\aggregation_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\aggregation_y.zip-7_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-7_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\aggregation_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip CenterParTree2.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip kmodes.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip PrincipalParTree.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip pyc_xmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip skl_birch.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip skl_OPTICS.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-3_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-3_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\cure-t0-2000n-2D_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip CenterParTree2.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip kmodes.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip PrincipalParTree.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip pyc_xmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip skl_birch.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip skl_OPTICS.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\cure-t1-2000n-2D_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t2-4k_y.zip CenterParTree2.csv',
#  'final_joined_result\\cure-t2-4k_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\cure-t2-4k_y.zip kmodes.csv',
#  'final_joined_result\\cure-t2-4k_y.zip PrincipalParTree.csv',
#  'final_joined_result\\cure-t2-4k_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\cure-t2-4k_y.zip pyc_xmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\cure-t2-4k_y.zip skl_birch.csv',
#  'final_joined_result\\cure-t2-4k_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\cure-t2-4k_y.zip skl_OPTICS.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-7_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-7_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\cure-t2-4k_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\german_credit_y.zip CenterParTree2.csv',
#  'final_joined_result\\german_credit_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\german_credit_y.zip kmodes.csv',
#  'final_joined_result\\german_credit_y.zip PrincipalParTree.csv',
#  'final_joined_result\\german_credit_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\german_credit_y.zip pyc_xmeans.csv',
#  'final_joined_result\\german_credit_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\german_credit_y.zip skl_birch.csv',
#  'final_joined_result\\german_credit_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\german_credit_y.zip skl_OPTICS.csv',
#  'final_joined_result\\german_credit_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\german_credit_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\german_credit_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\german_credit_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\german_credit_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\german_credit_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\german_credit_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\home.zip CenterParTree2.csv',
#  'final_joined_result\\home.zip ImpurityParTree2.csv',
#  'final_joined_result\\home.zip kmodes.csv',
#  'final_joined_result\\home.zip PrincipalParTree.csv',
#  'final_joined_result\\home.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\home.zip pyc_xmeans.csv',
#  'final_joined_result\\home.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\home.zip skl_birch.csv',
#  'final_joined_result\\home.zip skl_DBSCAN.csv',
#  'final_joined_result\\home.zip skl_OPTICS.csv',
#  'final_joined_result\\home.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\home.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\home.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\home.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\home.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\home.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\home.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\home.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\home.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\home.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\home.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\home.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\home.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\home.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\home.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\home.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\home.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\home.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\ionosphere_y.zip kmodes.csv',
#  'final_joined_result\\ionosphere_y.zip PrincipalParTree.csv',
#  'final_joined_result\\ionosphere_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\ionosphere_y.zip pyc_xmeans.csv',
#  'final_joined_result\\ionosphere_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\ionosphere_y.zip skl_birch.csv',
#  'final_joined_result\\ionosphere_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\ionosphere_y.zip skl_OPTICS.csv',
#  'final_joined_result\\ionosphere_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\ionosphere_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\ionosphere_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\ionosphere_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\ionosphere_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\ionosphere_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\ionosphere_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\iris_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\iris_y.zip kmodes.csv',
#  'final_joined_result\\iris_y.zip PrincipalParTree.csv',
#  'final_joined_result\\iris_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\iris_y.zip pyc_xmeans.csv',
#  'final_joined_result\\iris_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\iris_y.zip skl_birch.csv',
#  'final_joined_result\\iris_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\iris_y.zip skl_OPTICS.csv',
#  'final_joined_result\\iris_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\iris_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\iris_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\iris_y.zip-3_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-3_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\iris_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\iris_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\iris_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\iris_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\longsquare_y.zip CenterParTree2.csv',
#  'final_joined_result\\longsquare_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\longsquare_y.zip kmodes.csv',
#  'final_joined_result\\longsquare_y.zip PrincipalParTree.csv',
#  'final_joined_result\\longsquare_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\longsquare_y.zip pyc_xmeans.csv',
#  'final_joined_result\\longsquare_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\longsquare_y.zip skl_birch.csv',
#  'final_joined_result\\longsquare_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\longsquare_y.zip skl_OPTICS.csv',
#  'final_joined_result\\longsquare_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\longsquare_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\longsquare_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\longsquare_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\longsquare_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\longsquare_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\longsquare_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set1_y.zip CenterParTree2.csv',
#  'final_joined_result\\s-set1_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\s-set1_y.zip kmodes.csv',
#  'final_joined_result\\s-set1_y.zip PrincipalParTree.csv',
#  'final_joined_result\\s-set1_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\s-set1_y.zip pyc_xmeans.csv',
#  'final_joined_result\\s-set1_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\s-set1_y.zip skl_birch.csv',
#  'final_joined_result\\s-set1_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\s-set1_y.zip skl_OPTICS.csv',
#  'final_joined_result\\s-set1_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set1_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set1_y.zip-15_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-15_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set1_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set1_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set1_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\s-set1_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set2_y.zip CenterParTree2.csv',
#  'final_joined_result\\s-set2_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\s-set2_y.zip kmodes.csv',
#  'final_joined_result\\s-set2_y.zip PrincipalParTree.csv',
#  'final_joined_result\\s-set2_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\s-set2_y.zip pyc_xmeans.csv',
#  'final_joined_result\\s-set2_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\s-set2_y.zip skl_birch.csv',
#  'final_joined_result\\s-set2_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\s-set2_y.zip skl_OPTICS.csv',
#  'final_joined_result\\s-set2_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set2_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set2_y.zip-15_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-15_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set2_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set2_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\s-set2_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\s-set2_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\tetra_y.zip CenterParTree2.csv',
#  'final_joined_result\\tetra_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\tetra_y.zip kmodes.csv',
#  'final_joined_result\\tetra_y.zip PrincipalParTree.csv',
#  'final_joined_result\\tetra_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\tetra_y.zip pyc_xmeans.csv',
#  'final_joined_result\\tetra_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\tetra_y.zip skl_birch.csv',
#  'final_joined_result\\tetra_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\tetra_y.zip skl_OPTICS.csv',
#  'final_joined_result\\tetra_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\tetra_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\tetra_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\tetra_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\tetra_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\tetra_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\tetra_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\titanic_y.zip CenterParTree2.csv',
#  'final_joined_result\\titanic_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\titanic_y.zip kmodes.csv',
#  'final_joined_result\\titanic_y.zip PrincipalParTree.csv',
#  'final_joined_result\\titanic_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\titanic_y.zip pyc_xmeans.csv',
#  'final_joined_result\\titanic_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\titanic_y.zip skl_birch.csv',
#  'final_joined_result\\titanic_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\titanic_y.zip skl_OPTICS.csv',
#  'final_joined_result\\titanic_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\titanic_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\titanic_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\titanic_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\titanic_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\titanic_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\titanic_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle1_y.zip CenterParTree2.csv',
#  'final_joined_result\\triangle1_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\triangle1_y.zip kmodes.csv',
#  'final_joined_result\\triangle1_y.zip PrincipalParTree.csv',
#  'final_joined_result\\triangle1_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\triangle1_y.zip pyc_xmeans.csv',
#  'final_joined_result\\triangle1_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\triangle1_y.zip skl_birch.csv',
#  'final_joined_result\\triangle1_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\triangle1_y.zip skl_OPTICS.csv',
#  'final_joined_result\\triangle1_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle1_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle1_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle1_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle1_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle1_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\triangle1_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle2_y.zip CenterParTree2.csv',
#  'final_joined_result\\triangle2_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\triangle2_y.zip kmodes.csv',
#  'final_joined_result\\triangle2_y.zip PrincipalParTree.csv',
#  'final_joined_result\\triangle2_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\triangle2_y.zip pyc_xmeans.csv',
#  'final_joined_result\\triangle2_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\triangle2_y.zip skl_birch.csv',
#  'final_joined_result\\triangle2_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\triangle2_y.zip skl_OPTICS.csv',
#  'final_joined_result\\triangle2_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle2_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle2_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle2_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle2_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\triangle2_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\triangle2_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\vehicle_y.zip kmodes.csv',
#  'final_joined_result\\vehicle_y.zip PrincipalParTree.csv',
#  'final_joined_result\\vehicle_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\vehicle_y.zip pyc_xmeans.csv',
#  'final_joined_result\\vehicle_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\vehicle_y.zip skl_birch.csv',
#  'final_joined_result\\vehicle_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\vehicle_y.zip skl_OPTICS.csv',
#  'final_joined_result\\vehicle_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\vehicle_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\vehicle_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\vehicle_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\vehicle_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\vehicle_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\vehicle_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\wdbc_y.zip CenterParTree2.csv',
#  'final_joined_result\\wdbc_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\wdbc_y.zip kmodes.csv',
#  'final_joined_result\\wdbc_y.zip PrincipalParTree.csv',
#  'final_joined_result\\wdbc_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\wdbc_y.zip pyc_xmeans.csv',
#  'final_joined_result\\wdbc_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\wdbc_y.zip skl_birch.csv',
#  'final_joined_result\\wdbc_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\wdbc_y.zip skl_OPTICS.csv',
#  'final_joined_result\\wdbc_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\wdbc_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\wdbc_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\wdbc_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\wdbc_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\wdbc_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\wdbc_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\wine.zip CenterParTree2.csv',
#  'final_joined_result\\wine.zip ImpurityParTree2.csv',
#  'final_joined_result\\wine.zip kmodes.csv',
#  'final_joined_result\\wine.zip PrincipalParTree.csv',
#  'final_joined_result\\wine.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\wine.zip pyc_xmeans.csv',
#  'final_joined_result\\wine.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\wine.zip skl_birch.csv',
#  'final_joined_result\\wine.zip skl_DBSCAN.csv',
#  'final_joined_result\\wine.zip skl_OPTICS.csv',
#  'final_joined_result\\wine.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\wine.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\wine.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\wine.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\wine.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\wine.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\wine.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\wine.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\wine.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\wine.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\wine.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\wine.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\wine.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\wine.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\wine.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\wine.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\wine.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\wine.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik5_y.zip CenterParTree2.csv',
#  'final_joined_result\\zelnik5_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\zelnik5_y.zip kmodes.csv',
#  'final_joined_result\\zelnik5_y.zip PrincipalParTree.csv',
#  'final_joined_result\\zelnik5_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\zelnik5_y.zip pyc_xmeans.csv',
#  'final_joined_result\\zelnik5_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\zelnik5_y.zip skl_birch.csv',
#  'final_joined_result\\zelnik5_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\zelnik5_y.zip skl_OPTICS.csv',
#  'final_joined_result\\zelnik5_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik5_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik5_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik5_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik5_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik5_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\zelnik5_y.zip-8_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik6_y.zip CenterParTree2.csv',
#  'final_joined_result\\zelnik6_y.zip ImpurityParTree2.csv',
#  'final_joined_result\\zelnik6_y.zip kmodes.csv',
#  'final_joined_result\\zelnik6_y.zip PrincipalParTree.csv',
#  'final_joined_result\\zelnik6_y.zip pyc_agglomerativeClust.csv',
#  'final_joined_result\\zelnik6_y.zip pyc_xmeans.csv',
#  'final_joined_result\\zelnik6_y.zip skl_agglomerativeClust.csv',
#  'final_joined_result\\zelnik6_y.zip skl_birch.csv',
#  'final_joined_result\\zelnik6_y.zip skl_DBSCAN.csv',
#  'final_joined_result\\zelnik6_y.zip skl_OPTICS.csv',
#  'final_joined_result\\zelnik6_y.zip-10_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-10_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-10_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik6_y.zip-12_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-12_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-12_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik6_y.zip-2_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-2_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-2_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik6_y.zip-3_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-3_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-4_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-4_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-4_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik6_y.zip-6_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-6_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-6_True_k kmeans+dt.csv',
#  'final_joined_result\\zelnik6_y.zip-8_k skl_bis_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-8_k skl_kmeans.csv',
#  'final_joined_result\\zelnik6_y.zip-8_True_k kmeans+dt.csv']

# %%
df_Center = pd.read_csv("final_joined_result/2d-3c-no123_y.zip CenterParTree2.csv")
df_Impurity = pd.read_csv("final_joined_result/2d-3c-no123_y.zip ImpurityParTree2.csv")
df_Principal = pd.read_csv("final_joined_result/2d-3c-no123_y.zip PrincipalParTree.csv")

# %%
df_Center.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                 3                30                 50
# 1         10                 3                30                 50
# 2         10                 3                30                 50
# 3         10                 3                30                 50
# 4         10                 3                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state metric_con  \
# 0          1000.0               100.0      0.0            42        cos
# 1          1000.0               100.0      0.1            42        cos
# 2          1000.0               100.0      0.2            42        cos
# 3          1000.0                20.0      0.0            42        cos
# 4          1000.0                20.0      0.1            42        cos
#
#   metric_cat  ...  adj_rand  mut_info_score  adj_mutual_info_score  \
# 0    jaccard  ...    0.0000          0.0000                 0.0000
# 1    jaccard  ...    0.0009          0.0028                 0.0002
# 2    jaccard  ...    0.0009          0.0028                 0.0002
# 3    jaccard  ...    0.0000          0.0000                 0.0000
# 4    jaccard  ...    0.0009          0.0028                 0.0002
#
#    norm_mutual_info_score  homog_score  complete_score  v_msr_score  \
# 0                  0.0000       0.0000          1.0000       0.0000
# 1                  0.0057       0.0029          0.1319       0.0057
# 2                  0.0057       0.0029          0.1319       0.0057
# 3                  0.0000       0.0000          1.0000       0.0000
# 4                  0.0057       0.0029          0.1319       0.0057
#
#    fwlks_mallows_score             alg            dataset
# 0               0.6451  CenterParTree2  2d-3c-no123_y.zip
# 1               0.6437  CenterParTree2  2d-3c-no123_y.zip
# 2               0.6437  CenterParTree2  2d-3c-no123_y.zip
# 3               0.6451  CenterParTree2  2d-3c-no123_y.zip
# 4               0.6437  CenterParTree2  2d-3c-no123_y.zip
#
# [5 rows x 25 columns]

# %%
df_Impurity.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                10                30                 50
# 1         10                10                30                 50
# 2         10                10                30                 50
# 3         10                10                30                 50
# 4         10                10                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state criteria_clf  \
# 0          1000.0               100.0      0.0            42      entropy
# 1          1000.0               100.0      0.0            42      entropy
# 2          1000.0               100.0      0.0            42         gini
# 3          1000.0               100.0      0.0            42         gini
# 4          1000.0               100.0      0.0            42           me
#
#   criteria_reg  ...  adj_rand  mut_info_score  adj_mutual_info_score  \
# 0         mape  ...    0.3915          0.5734                 0.5251
# 1           r2  ...    0.0000          0.0000                 0.0000
# 2         mape  ...    0.3915          0.5734                 0.5251
# 3           r2  ...    0.0000          0.0000                 0.0000
# 4         mape  ...    0.3915          0.5734                 0.5251
#
#    norm_mutual_info_score  homog_score  complete_score  v_msr_score  \
# 0                  0.5269       0.6002          0.4696       0.5269
# 1                  0.0000       0.0000          1.0000       0.0000
# 2                  0.5269       0.6002          0.4696       0.5269
# 3                  0.0000       0.0000          1.0000       0.0000
# 4                  0.5269       0.6002          0.4696       0.5269
#
#    fwlks_mallows_score               alg            dataset
# 0               0.6197  ImpurityParTree2  2d-3c-no123_y.zip
# 1               0.6451  ImpurityParTree2  2d-3c-no123_y.zip
# 2               0.6197  ImpurityParTree2  2d-3c-no123_y.zip
# 3               0.6451  ImpurityParTree2  2d-3c-no123_y.zip
# 4               0.6197  ImpurityParTree2  2d-3c-no123_y.zip
#
# [5 rows x 25 columns]

# %%
df_Principal.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                10                30                 50
# 1         10                10                30                 50
# 2         10                10                30                 50
# 3         10                10                30                 50
# 4         10                10                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state  n_components  \
# 0          1000.0                 100      0.0            42             1
# 1          1000.0                 100      0.0            42             1
# 2          1000.0                 100      0.0            42             1
# 3          1000.0                 100      0.0            42             1
# 4          1000.0                 100      0.0            42             2
#
#    oblique_splits  ...  adj_rand  mut_info_score  adj_mutual_info_score  \
# 0           False  ...     0.768          0.7781                 0.7497
# 1           False  ...     0.768          0.7781                 0.7497
# 2           False  ...     0.768          0.7781                 0.7497
# 3           False  ...     0.768          0.7781                 0.7497
# 4           False  ...     0.768          0.7781                 0.7497
#
#    norm_mutual_info_score  homog_score  complete_score  v_msr_score  \
# 0                  0.7508       0.8144          0.6964       0.7508
# 1                  0.7508       0.8144          0.6964       0.7508
# 2                  0.7508       0.8144          0.6964       0.7508
# 3                  0.7508       0.8144          0.6964       0.7508
# 4                  0.7508       0.8144          0.6964       0.7508
#
#    fwlks_mallows_score               alg            dataset
# 0               0.8621  PrincipalParTree  2d-3c-no123_y.zip
# 1               0.8621  PrincipalParTree  2d-3c-no123_y.zip
# 2               0.8621  PrincipalParTree  2d-3c-no123_y.zip
# 3               0.8621  PrincipalParTree  2d-3c-no123_y.zip
# 4               0.8621  PrincipalParTree  2d-3c-no123_y.zip
#
# [5 rows x 26 columns]

# %%
df_concat = pd.concat([df_Center, df_Principal, df_Impurity])
df_concat.head()
# Out:
#    max_depth  max_nbr_clusters  min_samples_leaf  min_samples_split  \
# 0         10                 3                30                 50
# 1         10                 3                30                 50
# 2         10                 3                30                 50
# 3         10                 3                30                 50
# 4         10                 3                30                 50
#
#    max_nbr_values  max_nbr_values_cat  bic_eps  random_state metric_con  \
# 0          1000.0               100.0      0.0            42        cos
# 1          1000.0               100.0      0.1            42        cos
# 2          1000.0               100.0      0.2            42        cos
# 3          1000.0                20.0      0.0            42        cos
# 4          1000.0                20.0      0.1            42        cos
#
#   metric_cat  ...  complete_score  v_msr_score  fwlks_mallows_score  \
# 0    jaccard  ...          1.0000       0.0000               0.6451
# 1    jaccard  ...          0.1319       0.0057               0.6437
# 2    jaccard  ...          0.1319       0.0057               0.6437
# 3    jaccard  ...          1.0000       0.0000               0.6451
# 4    jaccard  ...          0.1319       0.0057               0.6437
#
#               alg            dataset  n_components  oblique_splits  \
# 0  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 1  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 2  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 3  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
# 4  CenterParTree2  2d-3c-no123_y.zip           NaN             NaN
#
#    max_oblique_features  criteria_clf  criteria_reg
# 0                   NaN           NaN           NaN
# 1                   NaN           NaN           NaN
# 2                   NaN           NaN           NaN
# 3                   NaN           NaN           NaN
# 4                   NaN           NaN           NaN
#
# [5 rows x 30 columns]

# %%
df_concat.groupby(by=["alg"])["silhouette"].max()
# Out:
# alg
# CenterParTree2      0.2779
# ImpurityParTree2    0.5375
# PrincipalParTree    0.5448
# Name: silhouette, dtype: float64

# %%
risultati_groupby_alg = dict()
risultati_groupby_dataset = dict()

for filename in risultati:
    alg = filename.split(" ")[-1][:-4]
    dataset = filename.split(" ")[0].split("\\")[-1][:-4]
    
    if alg not in risultati_groupby_alg:
        risultati_groupby_alg[alg] = []
    if dataset not in risultati_groupby_dataset:
        risultati_groupby_dataset[dataset] = []
    
    risultati_groupby_alg[alg].append(filename)
    risultati_groupby_dataset[dataset].append(filename)

# %%
res_values_uns = ["time", "silhouette", "calinski_harabasz", "davies_bouldin"]
res_values_sup = ["r_score", "adj_rand", "mut_info_score", "adj_mutual_info_score", "norm_mutual_info_score",
                                 "homog_score", "complete_score", "v_msr_score", "fwlks_mallows_score"]
res_values_all = res_values_uns + res_values_sup

# %% [raw]
# for dataset_name, filelist in risultati_groupby_dataset.items():
#     df_list = []
#     for filename in filelist:
#         df_list.append(pd.read_csv(filename))
#
#         #try:
#         #    df[-1] = df[-1][res_values_all]
#         #except:
#         df_list[-1] = df_list[-1][res_values_uns]
#
#         df_list[-1]["dataset_name"] = dataset_name
#
#     df = pd.concat(df_list)
#
#     for i, col in enumerate(df.drop(columns=["time", "dataset_name"]).columns):
#         plt.subplot(1, len(df.drop(columns=["time", "dataset_name"]).columns), i+1)
#
#         #df_plot = df.sort_values(by=[col])
#         df_plot = df.groupby(by=["dataset_name"])[col].max().reset_index()
#
#         #print(df_plot.head())
#
#         plt.scatter(df_plot.dataset_name, df_plot[col])
#         plt.title(col)
#
#     plt.suptitle(dataset_name)
#     plt.plot()

# %%
df = pd.DataFrame()
lista = []

datasets = set()
algorithms = set()

for filename in risultati:
    alg = filename.split(" ")[-1][:-4]
    dataset = filename.split(" ")[0].split("\\")[-1][:-4].replace(".zip", "").replace("-", "")
    
    datasets.add(dataset)
    algorithms.add(alg)
    
    lista.append(pd.read_csv(filename))
    
    lista[-1]["alg"] = alg
    if "wine" in dataset:
        lista[-1]["dataset"] = "wine"
    elif "home" in dataset:
        lista[-1]["dataset"] = "home"
    else:
        lista[-1]["dataset"] = dataset.split("_y")[0]+"_y"
    
df = pd.concat(lista)

df.columns
# Out:
# Index(['max_depth', 'max_nbr_clusters', 'min_samples_leaf',
#        'min_samples_split', 'max_nbr_values', 'max_nbr_values_cat', 'bic_eps',
#        'random_state', 'metric_con', 'metric_cat', 'time', 'silhouette',
#        'calinski_harabasz', 'davies_bouldin', 'r_score', 'adj_rand',
#        'mut_info_score', 'adj_mutual_info_score', 'norm_mutual_info_score',
#        'homog_score', 'complete_score', 'v_msr_score', 'fwlks_mallows_score',
#        'alg', 'dataset', 'criteria_clf', 'criteria_reg', 'n_clusters',
#        'max_iter', 'init', 'n_init', 'verbose', 'n_jobs', 'n_components',
#        'oblique_splits', 'max_oblique_features', 'number_clusters',
#        'amount_initial_centers', 'kmax', 'metric', 'linkage', 'threshold',
#        'branching_factor', 'eps', 'min_samples', 'algorithm', 'max_eps', 'tol',
#        'copy', 'bisecting_strategy', 'labels_as_tree_leaves', 'criterion',
#        'splitter', 'min_weight_fraction_leaf', 'max_features',
#        'max_leaf_nodes', 'min_impurity_decrease', 'class_weight', 'ccp_alpha'],
#       dtype='object')

# %%
algoritmi_grafico = ["PrincipalParTree", "CenterParTree2", "ImpurityParTree2"]

# %%
for col in res_values_all:
    if col == "time":
        continue

    df_plot = df.groupby(by=["dataset", "alg"])[[col, "time"]].max().reset_index()
    
    df_plot = df_plot[df_plot.alg.isin(algoritmi_grafico)]

    for alg in df_plot.alg.unique():
        plt.scatter(df_plot[df_plot.alg == alg].dataset, 
                    df_plot[df_plot.alg == alg][col], 
                    label=alg, 
                    #s=df_plot[df_plot.alg == alg].time
                   )

    plt.title(col)

    plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")

    plt.xticks(rotation=90)

    plt.show()

# %%
df.dataset.unique()
# Out:
# array(['2d20cno0_y', '2d3cno123_y', '2d4cno9_y', '2d4c_y', '2dd31_y',
#        'aggregation_y', 'curet02000n2D_y', 'curet12000n2D_y',
#        'curet24k_y', 'german_credit_y', 'home', 'ionosphere_y', 'iris_y',
#        'longsquare_y', 'sset1_y', 'sset2_y', 'tetra_y', 'titanic_y',
#        'triangle1_y', 'triangle2_y', 'vehicle_y', 'wdbc_y', 'wine',
#        'zelnik5_y', 'zelnik6_y'], dtype=object)

# %%
for col in res_values_all:
    if col == "time":
        continue

    df_plot = df.groupby(by=["dataset", "alg"])[[col, "time"]].max().reset_index()
    
    #df_plot = df_plot[df_plot.alg.isin(algoritmi_grafico)]
    
    colors = ["blue", 
              "darkorange", 
              "green", 
              "red", 
              "purple", 
              "brown", 
              "pink", 
              "gray", 
              "lime", 
              "cornflowerblue", 
              "aqua", 
              "yellow",
              "magenta"
             ]

    for i, alg in enumerate(df_plot.alg.unique()):
        plt.scatter(df_plot[df_plot.alg == alg].dataset, 
                    df_plot[df_plot.alg == alg][col], 
                    label=alg, 
                    #s=df_plot[df_plot.alg == alg].time
                    c=colors[i%len(colors)]
                   )

    plt.title(col)

    plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")

    plt.xticks(rotation=90)

    plt.show()

# %% [raw]
# df_max = df.groupby(by=["dataset", "alg"])["silhouette"].max().reset_index()
#
# res = []
#
# for dataset, alg, sil in tqdm(df_max[["dataset", "alg", "silhouette"]].values):
#     for row in df.values:
#         row_dict = dict((b, a) for a, b in zip(row, df.columns))
#
#         cond = row_dict["silhouette"] == sil and row_dict["alg"] == alg and row_dict["dataset"] == dataset
#
#         if cond:
#             res.append(row)
#
# #df[df.apply(lambda x: len(df_max[(df_max.silhouette == x["silhouette"]) & (df_max.alg == x["alg"]) & (df_max.dataset == x["dataset"])])>0, axis=1)]

# %%
df.dataset.equals(df_max.dataset)

# %%
df_max.dataset

# %%
import pandas as pd
import os 
from glob import glob
import numpy as np

# %%
datasets = datasets = [y for x in os.walk(".") for y in glob(os.path.join(x[0], '*.csv'))]
datasets
# Out:
# ['.\\adult.csv',
#  '.\\avila.csv',
#  '.\\bank.csv',
#  '.\\churn.csv',
#  '.\\compas-scores-two-years.csv',
#  '.\\diabetes.csv',
#  '.\\fico.csv',
#  '.\\german_credit.csv',
#  '.\\home.csv',
#  '.\\ionosphere.csv',
#  '.\\iris.csv',
#  '.\\titanic.csv',
#  '.\\vehicle.csv',
#  '.\\wdbc.csv',
#  '.\\wine.csv']

# %% [markdown]
# # Adult

# %%
df = pd.read_csv(datasets[0])
df.columns = df.columns.str.replace(' ', '')
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t-{name}-")
# Out:
# 9	0%	object	-workclass-
# 16	0%	object	-education-
# 7	0%	object	-marital-status-
# 15	0%	object	-occupation-
# 6	0%	object	-relationship-
# 5	0%	object	-race-
# 42	0%	object	-native-country-

# %%
df["education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df.to_csv(datasets[0].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[0])

# %% [markdown]
# # Avila

# %%
df = pd.read_csv(datasets[1])
df.head()
# Out:
#    intercolumnar distance  upper margin  lower margin  exploitation  \
# 0                0.266074     -0.165620      0.320980      0.483299
# 1                0.130292      0.870736     -3.210528      0.062493
# 2               -0.116585      0.069915      0.068476     -0.783147
# 3                0.031541      0.297600     -3.210528     -0.583590
# 4                0.229043      0.807926     -0.052442      0.082634
#
#    row number  modular ratio  interlinear spacing    weight  peak number  \
# 0    0.172340       0.273364             0.371178  0.929823     0.251173
# 1    0.261718       1.436060             1.465940  0.636203     0.282354
# 2    0.261718       0.439463            -0.081827 -0.888236    -0.123005
# 3   -0.721442      -0.307984             0.710932  1.051693     0.594169
# 4    0.261718       0.148790             0.635431  0.051062     0.032902
#
#    modular ratio/interlinear spacing class
# 0                           0.159345     A
# ...

# %%
df.to_csv(datasets[1].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[1])

# %% [markdown]
# # Bank

# %%
df = pd.read_csv(datasets[2], index_col=0)
df.head()
# Out:
#    give_credit  revolving  age  nbr_30_59_days_past_due_not_worse  debt_ratio  \
# 1            1   0.766127   45                                  2    0.802982
# 2            0   0.957151   40                                  0    0.121876
# 3            0   0.658180   38                                  1    0.085113
# 4            0   0.233810   30                                  0    0.036050
# 5            0   0.907239   49                                  1    0.024926
#
#    monthly_income  nbr_open_credits_and_loans  nbr_90_days_late  \
# 1          9120.0                          13                 0
# 2          2600.0                           4                 0
# 3          3042.0                           2                 1
# 4          3300.0                           5                 0
# 5         63588.0                           7                 0
#
#    nbr_real_estate_loans_or_lines  nbr_60_89_days_past_due_not_worse  \
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")

# %%
df.to_csv(datasets[2].replace(".csv", ".zip"), index=False)
os.remove(datasets[2])

# %% [markdown]
# # Churn

# %%
df = pd.read_csv(datasets[3])
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")
# Out:
# 51	0%	object	state
# 3333	0%	object	phone number

# %%
df.drop(columns=["phone number"], inplace=True)

# %%
df.to_csv(datasets[3].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[3])

# %% [markdown]
# # compas-scores-two-years

# %%
df = pd.read_csv(datasets[4])
df.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1947-04-18   69  Greater than 45             Other  ...               1
# 1  1982-01-22   34          25 - 45  African-American  ...               1
# 2  1991-05-14   24     Less than 25  African-American  ...               3
# 3  1993-01-21   23     Less than 25  African-American  ...               6
# 4  1973-01-22   43          25 - 45             Other  ...               1
#
# ...

# %%
df["dob"] = df["dob"].apply(lambda x: int(x.replace("-", "")))
df["compas_screening_date"] = df["compas_screening_date"].apply(lambda x: int(x.replace("-", "")))
df["c_jail_in"] = df["c_jail_in"].apply(lambda x: int(x[:10].replace("-", "")) if str(x) != "nan" else x)
df["c_jail_out"] = df["c_jail_out"].apply(lambda x: int(x[:10].replace("-", "")) if str(x) != "nan" else x)
df["c_offense_date"] = df["c_offense_date"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["c_arrest_date"] = df["c_arrest_date"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["screening_date"] = df["screening_date"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["v_screening_date"] = df["v_screening_date"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["in_custody"] = df["in_custody"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["out_custody"] = df["out_custody"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["r_offense_date"] = df["r_offense_date"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["r_jail_in"] = df["r_jail_in"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)
df["r_jail_out"] = df["r_jail_out"].apply(lambda x: int(x.replace("-", "")) if str(x) != "nan" else x)

# %%
df = df.drop(columns=["name", "first", "last", "c_case_number", "r_case_number", "vr_case_number", "vr_offense_date", 
                      "vr_charge_desc", "r_charge_desc", "c_charge_desc"])

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")
# Out:
# 10	51%	object	r_charge_degree

# %%
df.to_csv(datasets[4].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[4])

# %% [markdown]
# # diabetes

# %%
df = pd.read_csv(datasets[5])
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")

# %%
df.to_csv(datasets[5].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[5])

# %% [markdown]
# # fico

# %%
index = 6
df = pd.read_csv(datasets[index])
print(datasets[index])
df
# Out:
# .\fico.csv
#       RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0                 Bad                    55                    144
# 1                 Bad                    61                     58
# 2                 Bad                    67                     66
# 3                 Bad                    66                    169
# 4                 Bad                    81                    333
# ...               ...                   ...                    ...
# 10454            Good                    73                    131
# 10455             Bad                    65                    147
# 10456             Bad                    74                    129
# 10457             Bad                    72                    234
# 10458             Bad                    66                     28
#
#        MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                              4              84                     20
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")
# Out:
# 61	0%	int64	ExternalRiskEstimate
# 526	0%	int64	MSinceOldestTradeOpen
# 112	0%	int64	MSinceMostRecentTradeOpen
# 237	0%	int64	AverageMInFile
# 74	0%	int64	NumSatisfactoryTrades
# 19	0%	int64	NumTrades60Ever2DerogPubRec
# 17	0%	int64	NumTrades90Ever2DerogPubRec
# 72	0%	int64	PercentTradesNeverDelq
# 87	0%	int64	MSinceMostRecentDelq
# 10	0%	int64	MaxDelq2PublicRecLast12M
# 8	0%	int64	MaxDelqEver
# 88	0%	int64	NumTotalTrades
# 19	0%	int64	NumTradesOpeninLast12M
# 96	0%	int64	PercentInstallTrades
# 28	0%	int64	MSinceMostRecentInqexcl7days
# 27	0%	int64	NumInqLast6M
# 27	0%	int64	NumInqLast6Mexcl7days
# 128	0%	int64	NetFractionRevolvingBurden
# 139	0%	int64	NetFractionInstallBurden
# 31	0%	int64	NumRevolvingTradesWBalance
# 20	0%	int64	NumInstallTradesWBalance
# 19	0%	int64	NumBank2NatlTradesWHighUtilization
# 95	0%	int64	PercentTradesWBalance

# %%
df.to_csv(datasets[index].replace(".csv", ".zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # german_credit

# %%
index = 7
df = pd.read_csv(datasets[index])
print(datasets[index])
df = df[list(df.columns[1:])+["default"]]
df.head()
# Out:
# .\german_credit.csv
#   account_check_status  duration_in_month  \
# 0               < 0 DM                  6
# 1    0 <= ... < 200 DM                 48
# 2  no checking account                 12
# 3               < 0 DM                 42
# 4               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")
# Out:
# 5	0%	object	credit_history
# 10	0%	object	purpose
# 5	0%	object	savings
# 5	0%	object	present_emp_since

# %%
df.to_csv(datasets[index].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # home

# %%
index = 8
df = pd.read_csv(datasets[index])
print(datasets[index])
df.head()
# Out:
# .\home.csv
#    in_sf  beds  bath    price  year_built  sqft  price_per_sqft  elevation
# 0      0   2.0   1.0   999000        1960  1000             999         10
# 1      0   2.0   2.0  2750000        2006  1418            1939          0
# 2      0   2.0   2.0  1350000        1900  2150             628          9
# 3      0   1.0   1.0   629000        1903   500            1258          9
# 4      0   0.0   1.0   439000        1930   500             878         10

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")

# %%
df.to_csv(datasets[index].replace(".csv", ".zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # ionosphere

# %%
index = 9
df = pd.read_csv(datasets[index])
print(datasets[index])
df.head()
# Out:
# .\ionosphere.csv
#    a01  a02      a03      a04      a05      a06      a07      a08      a09  \
# 0    1    0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1    1    0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2    1    0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3    1    0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4    1    0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        a10  ...      a26      a27      a28      a29      a30      a31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        a32      a33      a34  class
# 0 -0.54487  0.18641 -0.45300      g
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")

# %%
df.to_csv(datasets[index].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # iris

# %%
index = 10
df = pd.read_csv(datasets[index])
print(datasets[index])
df.head()
# Out:
# .\iris.csv
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.to_csv(datasets[index].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # titanic

# %%
index = 11
df = pd.read_csv(datasets[index])
print(datasets[index])
df = df[list(df.drop(columns=["Survived"]))+["Survived"]]
df.head()
# Out:
# .\titanic.csv
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# ...

# %%
for na, (name, count), tipo in zip(df.isna().sum(), df.nunique().items(), df.dtypes):
    if tipo != object or count < 5:
        continue
    print(f"{count}\t{na*100//len(df)}%\t{tipo}\t{name}")
# Out:
# 891	0%	object	Name
# 681	0%	object	Ticket
# 147	77%	object	Cabin

# %%
df["Cabin_letter"] = df["Cabin"].apply(lambda x: str(x[0]) if str(x) != "nan" else x)
df["Cabin_n"] = df["Cabin"].apply(lambda x: int(x.replace("F ", "")[1:4]) if str(x) != "nan" and x.replace("F ", "")[1:4] != '' else x)
df = df.drop(columns=["Name", "Ticket", "Cabin"])

# %%
df[list(df.drop(columns=["Survived"]))+["Survived"]]
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0              1       3    male  22.0      1      0   7.2500        S
# 1              2       1  female  38.0      1      0  71.2833        C
# 2              3       3  female  26.0      0      0   7.9250        S
# 3              4       1  female  35.0      1      0  53.1000        S
# 4              5       3    male  35.0      0      0   8.0500        S
# ..           ...     ...     ...   ...    ...    ...      ...      ...
# 886          887       2    male  27.0      0      0  13.0000        S
# 887          888       1  female  19.0      0      0  30.0000        S
# 888          889       3  female   NaN      1      2  23.4500        S
# 889          890       1    male  26.0      0      0  30.0000        C
# 890          891       3    male  32.0      0      0   7.7500        Q
#
#     Cabin_letter Cabin_n  Survived
# 0            NaN     NaN         0
# 1              C      85         1
# ...

# %%
df[list(df.drop(columns=["Survived"]))+["Survived"]].to_csv(datasets[index].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # vehicle

# %%
index = 12
df = pd.read_csv(datasets[index])
print(datasets[index])
df.head()
# Out:
# .\vehicle.csv
#    COMPACTNESS  CIRCULARITY  DISTANCE CIRCULARITY  RADIUS RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS ASPECT RATIO  MAX.LENGTH ASPECT RATIO  SCATTER RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS RECTANGULARITY  MAX.LENGTH RECTANGULARITY  \
# 0             42                      20                        159
# ...

# %%
df.to_csv(datasets[index].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # wdbc

# %%
index = 13
df = pd.read_csv(datasets[index], index_col=0)
print(datasets[index])
df.head()
# Out:
# .\wdbc.csv
#          diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           mean smoothness  mean compactness  mean concavity  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           mean concave points  mean symmetry  ...  worst radius  \
# id                                            ...
# ...

# %%
df[list(df.drop(columns=["diagnosis"]))+["diagnosis"]].to_csv(datasets[index].replace(".csv", "_y.zip"), index=False)
os.remove(datasets[index])

# %% [markdown]
# # wine

# %%
index = 14
df = pd.read_csv(datasets[index])
print(datasets[index])
df.head()
# Out:
# .\wine.csv
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4      5r
# 1      9.8      5r
# ...

# %%
df.to_csv(datasets[index].replace(".csv", ".zip"), index=False)
os.remove(datasets[index])
